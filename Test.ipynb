# %%
import ee
import geemap as emap
try:
    ee.Initialize()
except:
    ee.Authenticate()
    ee.Initialize()

# %%
states = ee.FeatureCollection('TIGER/2018/States').sort('ALAND', False)

sd=states.flatten()
try:
    sd=states.fatten()
    print(sd)
except:
    print("Error occurred")
# Out:
# Error occurred

# %%
states.first().toDictionary().getInfo()
# Out:
# {'ALAND': 1478839695958,
#  'AWATER': 245481577452,
#  'DIVISION': '9',
#  'FUNCSTAT': 'A',
#  'GEOID': '02',
#  'INTPTLAT': '+63.3473560',
#  'INTPTLON': '-152.8397334',
#  'LSAD': '00',
#  'MTFCC': 'G4000',
#  'NAME': 'Alaska',
#  'REGION': '4',
#  'STATEFP': '02',
#  'STATENS': '01785533',
#  'STUSPS': 'AK'}

# %%
value=states.aggregate_array("DIVISION").getInfo()

print(value)
# Out:
# ['9', '7', '9', '8', '8', '8', '8', '8', '8', '9', '8', '8', '4', '4', '4', '4', '4', '4', '7', '9', '5', '3', '4', '3', '3', '5', '7', '6', '5', '2', '6', '2', '7', '6', '3', '6', '5', '3', '1', '5', '5', '5', '1', '1', '1', '2', '9', '1', '0', '5', '1', '0', '0', '0', '0', '5']

# %%
areas=states.aggregate_histogram("ALAND").getInfo()
print(areas)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-95d986bec568> in <module>
# ----> 1 areas=states.aggregate_histogram("ALAND").getInfo()
#       2 print(areas)
#
# NameError: name 'states' is not defined

# %%
plt.bar(mydf.Name, mydf.Area)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
